# %%
Name:  Ayesha Jabbar
Internship: Cognifyz
Duration: 1 month

# %%
NAME OF PROJECT: ZOMATO RESTUARANTS' AGGREGATE RATINGS PREDICTION

# %%
#Who does not know Zomato Restaurants in today's era, which has both table booking and online booking also, providing easy access to food itesms.
#Lets have a look into the world of Zomato Restaurants.

# %%
Source of data: I have imported this dataset from Kaggle, downloaded into my PC and loaded it here in Jupyter notebook using pd.read_csv.

# %%
LEVEL 1:  TASK:1     Data Exploration and Preprocessing

# %%
Explore the dataset and identify the number of rows and columns.

#Importing the requried libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Dataset.csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
The dataset has 9551 total rows and 21 columns or features out of which one is target variable. The details are given below

# %%
#Listing all the columns or features of the Zomato dataset
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
Breif discussion about the data.

Lets understand each column in the dataset:

Restaurant ID: The id for each restaurant, which is unique. 
Restaurant Name: The name of the restaurant.
Country Code: Details of the country where the restaurant is located.
City: The city where the restaurant is located.
Address: This is the address of the restaurant.
Locality: As the column name itself is suggesting, so is the locality of the restaurant.
Locality Verbose: This column is just a detailed extension of the locality information.
Longitude: Longitude location of the restaurant.
Latitude: Latitude location of the restaurant. 
Cuisines: Different varieties or kinds of foods offered.
Currency: The currency of the country.
Has Table booking: This column gives us the information if there is an option for advance table booking or not in the particular restaurant.
Has Online delivery: Information if the restaurant has online food delivery or not.
Is delivering now: This column again specifies if the restaurant is delivering the order at the current time. 
Switch to order menu: Whether switch to order menu is available and also it has a single value throughout the data.
Price range: The price range of the restaurant.
Votes: Shows the number of votes for various restaurants for different ratings.
Average Cost for two: The cost for two people.
Aggregate rating: This is the target variable and it is the final rating of the restaurant.

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.tail(2)
# Out:
#       Restaurant ID           Restaurant Name  Country Code      City  \
# 9549        5916112                Assk Kahve           208  Istanbul
# 9550        5927402  Walter's Coffee Roastery           208  Istanbul
#
#                                                 Address   Locality  \
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kurucesme
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...       Moda
#
#          Locality Verbose  Longitude   Latitude         Cuisines  ...  \
# 9549  Kurucesme, Istanbul  29.036019  41.057979  Restaurant Cafe  ...
# 9550       Moda, Istanbul  29.026016  40.984776             Cafe  ...
#
#               Currency Has Table booking Has Online delivery  \
# 9549  Turkish Lira(TL)                No                  No
# 9550  Turkish Lira(TL)                No                  No
#
#      Is delivering now Switch to order menu Price range  Aggregate rating  \
# ...

# %%
The top 5 rows are perfect with no blanks or errors in the spellings of the column values.  But the bottom 5 rows show a lot of errors in the 
column values, which am going to correct with correct spellings.

# %%
#Locating City values having ��stanbul 
df.loc[df['City']=='��stanbul']
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9537        5904116       J'adore Chocolatier           208  ��stanbul
# 9538        5901782                 Starbucks           208  ��stanbul
# 9539        5902117                   Valonia           208  ��stanbul
# 9540        5927248          Draft Gastro Pub           208  ��stanbul
# 9541        5905215           Emirgan S�_ti��           208  ��stanbul
# 9542        5926979            Leman K�_lt�_r           208  ��stanbul
# 9543        5916085              Dem Karak�_y           208  ��stanbul
# 9544        5915547     Karak�_y G�_ll�_o��lu           208  ��stanbul
# 9545        5915054                  Baltazar           208  ��stanbul
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# ...

# %%
df['City']=df['City'].replace('��stanbul','Istanbul')

# %%
# I have listed and replaced all the other columns with the correct spellings respectively. Since each operation is taking a lot of space, I have
just mentioned just the commands and did not execute them here for neatness.

# %%
df.loc[df['Locality Verbose']=='Karak�_y, ��stanbul']
df.loc[df['Restaurant Name']=='Ceviz A��ac۱']
df.loc[df['Locality Verbose']=='Ko��uyolu, ��stanbul']
df.loc[df['Locality Verbose']=='Ko��uyolu, ��stanbul']

# %%
#I am replacing the wrong spelling with the right ones using the replace command.

# %%
df['Restaurant Name']=df['Restaurant Name'].replace('A���k Kahve','Assk Kahve')

# %%
df['Restaurant Name']=df['Restaurant Name'].replace('Ceviz A��ac۱','Ceviz Agaci')

# %%
df['Locality Verbose']=df['Locality Verbose'].replace('Ko��uyolu, ��stanbul','Kosuyolu, Istanbul')

# %%
df['Locality Verbose']=df['Locality Verbose'].replace('Karak�_y, ��stanbul', 'Karakoy Istanbul')

# %%
df['Locality']=df['Locality'].replace('Karak�_y','Karakoy')

# %%
df['Address']=df['Address'].replace('Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...','Kemankes Karamustafa Pasa Mahallesi, R۱ht۱m ...')

# %%
df['Locality Verbose']=df['Locality Verbose'].replace('Kuru�_e��me, ��stanbul', 'Kurucesme, Istanbul')

# %%
df['Locality']=df['Locality'].replace('Kuru�_e��me','Kurucesme')

# %%
df['Locality Verbose']=df['Locality Verbose'].replace('Moda, ��stanbul', 'Moda, Istanbul')

# %%
df['Locality']=df['Locality'].replace('Ko��uyolu','Kosuyolu')

# %%
#Some basic coding to thoroughly study the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#Information Details
1. We can see that there are 21 columns in total out of which 8 columns are numerical columns and others are object type. 
2. Restaurant ID, Country code, Average Cost for two, Price range, and Votes have integer datatypes. Latitude, Longitude, Aggregate rating are of
   float values.
3. Cuisines attribute has 9542 non-null values, so here missing values need to be replaced with appropriate values.
4. All other attributes have 9551 non-null values, so it is clear that these columns are perfect with no missing values.
5. The Aggregate rating feature is of float data type. 
6. Memorty usage is 1.5+ MB
7. Data ranges from 0 to 9550.

# %%
#Now lets determine value_counts of each variable to trace any wide spaces or null values

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Restaurant ID
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: count, Length: 9551, dtype: int64
#
#
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64
#
#
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64
#
#
# City
# New Delhi           5473
# Gurgaon             1118
# ...

# %%
After going through details of each variable, I found no widespaces. So we can move forward with next steps.

# %%
#Checking for missing values or null values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
There are 9 missing values in the Cuisines column. This is of object data type and I am going to fill the missing values with mode
(most frequently occuring value).
All the other features do not have any missing values.

# %%
df['Cuisines']=df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
Finally, we have dealt with the null values and now, we can proceed with the Descriptive Statistics

# %%
#Renaming some of the lengthy column names into short and appropriate names

# %%
df.rename(columns={'Average Cost for two':'Cost', 'Has Table booking':'Table_booking','Aggregate rating':'Aggregate_rating'}, inplace=True)

# %%
df.rename(columns={'Has Online delivery':'Online_delivery','Is delivering now':'Current_status'}, inplace=True)

# %%
df.head(2) #Renamed columns
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Table_booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)           Yes
# 1                    Japanese  ...  Botswana Pula(P)           Yes
#
# ...

# %%
#Diving into further details of the Zomato real-time data 
Lets look into unique values of every column. To make it easier, I have framed it in a DataFrame

# %%
df.nunique().to_frame('Unique Values')
# Out:
#                       Unique Values
# Restaurant ID                  9551
# Restaurant Name                7446
# Country Code                     15
# City                            141
# Address                        8918
# Locality                       1208
# Locality Verbose               1265
# Longitude                      8120
# Latitude                       8677
# Cuisines                       1825
# Cost                            140
# Currency                         12
# Table_booking                     2
# Online_delivery                   2
# Current_status                    2
# Switch to order menu              1
# Price range                       4
# Aggregate_rating                 33
# Rating color                      6
# Rating text                       6
# Votes                          1012

# %%
OBSERVATIONS:
1. The Restaurant ID column has total 9551 values, which are total number of rows also. We can understand that each value is unique here. 
2. Restaurant Name has 7446 unique names. So few of the names must be repetaing.
3. Address, Longitude, Latitude have approximately around 8000 values.
4. Table_booking, Online_delivery, Current_status have just 2 unique values. 
5. Switch to order menu on the other hand has just 1 unique value, which will not contribute anything to the data.
6. Price range, Rating color, Rating text have approximately 4, 6, 6 values. So these columns have different categories to which customers belong.
7. Cost column has 140 unique values. There are 140 different prices of the cuisines. Other variables have their values respectively.
8. Finally, is our target column 'Aggregate_rating', which has 33 unique values. These start from 0 to 4.9.

# %%
#Checking for unique values of the target variable which is 'Aggregate_rating'

# %%
df['Aggregate_rating'].nunique()
# Out:
# 33

# %%
#Discussing distribution of the target variable

# %%
df['Aggregate_rating'].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate_rating, dtype: float64

# %%
The describe method shows all the mean, minimum, median, standard deviation and other values of the target variable here

# %%
plt.hist(df['Aggregate_rating'])
plt.xlabel('Aggregate_rating')
plt.ylabel('Number of observations')
plt.title('Distribution of target variable')
plt.show()

# %%
There above distribution looks almost normal and there are 33 values, so there is no class imbalance noted here.

# %%
sns.countplot(data=df, x='Aggregate_rating')
plt.xticks(rotation=90)
df['Aggregate_rating'].value_counts()
plt.title("Countplot of Aggregate_rating", fontsize=20)
df['Aggregate_rating'].value_counts()
# Out:
# Aggregate_rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
The countplot of Aggregate_rating which is our target variable shows a maximum at 0.0, which means majority of them have not rated.  Again we can 
see a slight increase for ratings from 3.0 to 4.0.

There is no class imbalance here as there are 33 values

# %%
There are 33 unique values of the Target variable that is 'Aggregate_rating'. Total rows are 9551 and I have 33 unique values here.  So I can clearly
consider this as a multiple linear regression problem statment.  We can solve this with the help of regression based algorithms like LinearRegression,
DecisionTree regressor, and other regression based algorithms.

# %%
#Splitting numerical columns and categorical columns

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print ("Numerical Columns are:", numerical_col)
# Out:
# Numerical Columns are: ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Cost', 'Price range', 'Aggregate_rating', 'Votes']

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print ("Categorical Columns are:", categorical_col)
# Out:
# Categorical Columns are: ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Table_booking', 'Online_delivery', 'Current_status', 'Switch to order menu', 'Rating color', 'Rating text']

# %%
LEVEL:1    TASK:2        Descriptive Statistical Summary

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude           Cost  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000    9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381    1199.210763
# std     8.791521e+06     56.750546    41.467058    11.007935   16121.183073
# min     5.300000e+01      1.000000  -157.948486   -41.330428       0.000000
# 25%     3.019625e+05      1.000000    77.081343    28.478713     250.000000
# 50%     6.004089e+06      1.000000    77.191964    28.570469     400.000000
# 75%     1.835229e+07      1.000000    77.282006    28.642758     700.000000
# max     1.850065e+07    216.000000   174.832089    55.976980  800000.000000
#
#        Price range  Aggregate_rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# ...

# %%
We can get th mean values of numerical columns in the mean section of the table. Median values are the 50% values in table. Standard deviation 
values can also be noted respetively. Other observations are written below:

# %%
OBSERVATIONS:

1.  All the row counts are equal, which means no missing or NaN values. There are some negative values noted here.
2.  Mean is greater than median for the columns Resaurant ID, Country Code, Average Cost for two, and Votes.  It is right-sided skewed curve but
    for the rate column, mean is lesser than median, which means there is a left-skewness noted. The Longitude, Latitude, Price range and 
    Aggregrate rating columns have a mean lesser than median, which means left-sided skewness.              
3.  Outliers: The Restaurant ID column shows no outliers and going forward this columns needs to be removed as it adds no value to data. 
    All the rest of the columns have high number of outliers.  We will try to remove outliers going forward.
4.  Min values:  Minimum values are 0 (zero) for Average Cost for two, Aggregate rating and Votes. Country code and Price range columns have 1
    as their minimum values and Longitude and Latitude columns have negative values at their lowest points.
5.  Standard Deviation: Except for Price range and Aggregate rating, other columns have high standard deviation.

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print ("Categorical Columns are:", categorical_col)
# Out:
# Categorical Columns are: ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Table_booking', 'Online_delivery', 'Current_status', 'Switch to order menu', 'Rating color', 'Rating text']

# %%
Distribution of categorical columns such as Country Code, City and Cuisines

# %%
for col in df.select_dtypes(include=['object']):
  print(f"Distribution of {col}:")
  print(df[col].value_counts().sort_values(ascending=False).head(10))
# Out:
# Distribution of Restaurant Name:
# Restaurant Name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Keventers           34
# Pizza Hut           30
# Giani               29
# Baskin Robbins      28
# Barbeque Nation     26
# Name: count, dtype: int64
# Distribution of City:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Name: count, dtype: int64
# Distribution of Address:
# Address
# Dilli Haat, INA, New Delhi                                                    11
# Sector 41, Noida                                                              11
# Greater Kailash (GK) 1, New Delhi                                             10
# The Imperial, Janpath, New Delhi                                               9
# ...

# %%
We can note the distribution of all the categorical variables.

# %%
Identify the top cuisines and cities with the highest number of restaurants....

# %%
cuisines=df['Cuisines'].value_counts()[:10]
sns.barplot(x=cuisines,y=cuisines.index)
plt.xlabel('Count of Cuisines')
plt.title("Top 10 popular cuisines")
df['Cuisines'].value_counts()[:10]
# Out:
# Cuisines
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
The value.counts give the details of the top 10 Cuisines and their counts.
The top 10 Cuisines are North Indian with 945 counts followed by Chinese at 511 counts. Similarly, we have Fast Food at 354, North Indian,
Mughal. 
Cafe and Bakery have 299 and 218 respectively.  The least 2 cuisines are Desserts and Street food at 179 and 149.

# %%
#Cities with maximum number of Restaurants

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df['City'].value_counts().head(10), y=df['City'].value_counts().head(10).index)
plt.xlabel('Number of restaurants')
plt.title('Cities with highest number of Restaurants by Zomato')
df['City'].value_counts()[:10]
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
We will analyse just 10 number of values from total of 9551 rows for easy reference and understanding.

New Delhi has highest number of restaurants among all cities with 5473 restaurants followed by Gurgaon which has 1118 restaurants
Noida has 1080, Faridabad has 251, Ghaziabad at 25, Bhubaneshwar at 21, Amritsar at 21, Ahmedabad at 21, Lucknow has 21 and least is Guwahati at 21.

# %%
LEVEL:1    TASK:3  GEOSPATIAL ANALYSIS

# %%
Visualize the locations of restaurants on a map using latitude and longitude information.

# %%
Analyzing the distribution of restaurants across different cities or countries.

# %%
city_groups=df.groupby('City')

# %%
city_res_counts = city_groups.size().head(10).sort_values(ascending=False)

# %%
city_res_counts.plot(kind='bar')
plt.xlabel('City')
plt.ylabel('Number of restaurants')
plt.title('Restaurant distribution of city')
plt.show()

# %%
From the graph, Ahmedabad and Amritsar have the highest number of restaurants. Armidale has the lowest number of restuarants here.

# %%
Determine if there is any correlation between the restaurant's location and its rating

# %%
Corr=df[['Longitude', 'Latitude','Aggregate_rating']].corr()
print("Correlation between Longitude and Latitude with Aggregate_rating")
print(Corr)
# Out:
# Correlation between Longitude and Latitude with Aggregate_rating
#                   Longitude  Latitude  Aggregate_rating
# Longitude          1.000000  0.043207         -0.116818
# Latitude           0.043207  1.000000          0.000516
# Aggregate_rating  -0.116818  0.000516          1.000000

# %%
Correlation between Aggregate rating and longitude is -0.116818 which is a negative value, which means negative or weak correlation.
Correlation between Aggregate rating and latitude is 0.000516 which is positive but almost equal to 0, that means very weak positive relation or
no significant relationship.

# %%
LEVEL:2   TASK:1     Task: Table Booking and Online Delivery 
Determine the percentage of restaurants that offer table booking and online delivery

# %%
table_booking_count=df['Table_booking'].value_counts()

# %%
online_delivery_count=df['Online_delivery'].value_counts()

# %%
table_booking_percentage= (table_booking_count-df.shape[0])*100

# %%
online_delivery_percentage =(online_delivery_count-df.shape[0])*100

# %%
print("Percentage of restaurants that offer table booking:")
print(table_booking_percentage)
print("\nPercentage of restaurants that offer online delivery:")
print(online_delivery_percentage)
# Out:
# Percentage of restaurants that offer table booking:
# Table_booking
# No    -115800
# Yes   -839300
# Name: count, dtype: int64
#
# Percentage of restaurants that offer online delivery:
# Online_delivery
# No    -245100
# Yes   -710000
# Name: count, dtype: int64

# %%
Compare the average ratings of restaurants with table booking and those without

# %%
average_ratings_with_table_booking=df[df['Table_booking']=='Yes']['Aggregate_rating'].mean()

# %%
average_ratings_without_table_booking=df[df['Table_booking']=='No']['Aggregate_rating'].mean()

# %%
print("Average ratings for restaurants with table booking:", average_ratings_with_table_booking)
print("Average ratings for restaurants without table booking:", average_ratings_without_table_booking)
# Out:
# Average ratings for restaurants with table booking: 3.4419689119170984
# Average ratings for restaurants without table booking: 2.559358989634219

# %%
Average ratings with Table booking is 3.442 and without Table booking is 2.560

# %%
Analyze the availability of online delivery among restaurants with different price ranges

# %%
online_delivery_price_range=df.groupby('Price range')['Online_delivery'].value_counts().loc[:, 'Yes']*100

# %%
print("Online Delivery percentage according to Price Range")
print(online_delivery_price_range)
# Out:
# Online Delivery percentage according to Price Range
# Price range
# 1     70100
# 2    128600
# 3     41100
# 4      5300
# Name: count, dtype: int64

# %%
The Price range 1 has 70100, 2 has 128600, 3 has 41100 and 4 has 5300.

# %%
Level 2           Task 2:            Price Range Analysis

# %%
Determine the most common price range among all the restaurants

# %%
price_range_counts=df['Price range'].value_counts()
price_range_counts
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
most_common_price_range=price_range_counts.mode()[0]
print("The most common price range is:", most_common_price_range)
# Out:
# The most common price range is: 586

# %%
Calculate the average rating for each price range

# %%
average_rating_price_range=df.groupby('Price range')['Aggregate_rating'].mean()

# %%
print("Average rating for each price range:", average_rating_price_range)
# Out:
# Average rating for each price range: Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate_rating, dtype: float64

# %%
Identify the color that represents the highest average rating among different price ranges

# %%
avg_rating_per_price_range = df.groupby('Price range')['Aggregate_rating'].mean()

# %%
highest_range = avg_rating_per_price_range.idxmax()
highest_rating = avg_rating_per_price_range.max()

# %%
LEVEL:2  TASK:3      Task: Feature Engineering
Extract additional features from the existing columns, such as the length of the restaurant name or address.

# %%
#Extracting lenght of Restaurant Name
df['Legth_Restaurant_Name'] = df['Restaurant Name'].str.len()

# %%
# Extracting length of address
df['Length_of_address'] = df['Address'].str.len()

# %%
df.columns #We can see extra columns 'Lenght_Restaurant_Name' and Lenght_of_address are present in the dataset
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Cost', 'Currency', 'Table_booking', 'Online_delivery',
#        'Current_status', 'Switch to order menu', 'Price range',
#        'Aggregate_rating', 'Rating color', 'Rating text', 'Votes',
#        'Legth_Restaurant_Name', 'Length_of_address'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Online_delivery Current_status  \
# 0  French, Japanese, Desserts  ...               No             No
#
#   Switch to order menu Price range Aggregate_rating Rating color  Rating text  \
# 0                   No           3              4.8   Dark Green    Excellent
#
#    Votes Legth_Restaurant_Name Length_of_address
# 0    314                    16                71
#
# [1 rows x 23 columns]

# %%
DataFrame showing 16 characters as first value in Lenght_Restaurant_Name and Lenght_of_address showing 71 characters

# %%
Create new features like "Has Table Booking" or "Has Online Delivery" by encoding categorical variables.

# %%
The columns have been renamed as Table_booking and Online_delivery

# %%
# Encoding categorical variables using get_dummies
df_encoded_variables = pd.get_dummies(df, columns=['Table_booking', 'Online_delivery'])
print(df_encoded_variables.head())
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
LEVEL: 3       TASK:1       Task: Predictive Modeling

# %%
Build a regression model to predict the aggregate rating of a restaurant based on available features. Split the dataset into training and testing
sets and evaluate the model's performance using appropriate metrics.

# %%
I am plotting various graphs for visualizations as part of Algorithms

# %%
#Now lets move one to Graphical Analysis to showcase our data and draw meaningful insights for bussiness purpose and easy understanding of
#relationships between variables.

# %%
#Univariate Analysis: This involves only one variable for analysis.

# %%
#Count Plots

# %%
sns.countplot(data=df, x='Aggregate_rating')
plt.xticks(rotation=90)
df['Aggregate_rating'].value_counts()
plt.title("Countplot of Aggregate_rating", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Countplot of Aggregate_rating')

# %%
The countplot of Aggregate_rating which is our target variable shows a maximum at 0.0, which means majority of them have not rated.  Again we can 
see a slight increase for ratings 3.0 to 4.0.

# %%
#Plot for'Rating color'    
sns.countplot(data=df, x='Rating color')
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
Again it is similar to the above graph. We can see the Orange color has maxium count for which Rating text is Average. Red indicates poor and it stands
at the lowest value. WE have yellow followed by orange and Green and Dark Green.

# %%
#Grouping all the rating columns into a DataFrame

# %%
#Lets analyse by visualizing the above information

# %%
sns.countplot(data=df, x='Price range')
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
The graph shows 4 different ranges in prices and maximum customers chose range 1 and least opt for price range of 4.

# %%
#Plot to check if restaurant is delivering right away or not

# %%
sns.countplot(data=df, x='Current_status')
df['Current_status'].value_counts()
# Out:
# Current_status
# No     9517
# Yes      34
# Name: count, dtype: int64

# %%
Current status plot shows that most of the restaurants are not delivering right away.  Only a few of them are delivering now.

# %%
#Distribution plot using histogram

# %%
df.hist(bins=20, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Restaurant ID'}>,
#         <Axes: title={'center': 'Country Code'}>,
#         <Axes: title={'center': 'Longitude'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Cost'}>,
#         <Axes: title={'center': 'Price range'}>],
#        [<Axes: title={'center': 'Aggregate_rating'}>,
#         <Axes: title={'center': 'Votes'}>, <Axes: >]], dtype=object)

# %%
1. Right Skewness: The graph shows a right-sided curve for Country code, Cost, Price range, and Votes columns. 
2. Left Skewness: Both the Longitude and Latitude columns have left tailed curve.
3. Aggregate_rating has a normalized slightly right-sided skewness.
4. Restaurant ID is neutral

# %%
#Bivariate Analysis, uses 2 parameters, showing relationship between those parameters.
#Lets try to plot different relationships using different kinds like scatterplots, linear model plots etc...

# %%
#Boxplots for detecting outliers

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 25))
p=1
for column in numerical_col:
    if p<=17:
        plt.subplot(5,4,p)
        df.boxplot([column])
    p+=1
plt.show()

# %%
The boxplots show that except Restaurant ID column,all numerical columns have outliers. Votes and Cost have a lot ofoutliers.
Outliers need not be calculated for target variable.
# Considing the features on which zscore needs to be applied

# %%
features=df[['Country Code','Longitude','Latitude','Cost','Price range','Votes']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))

# %%
np.where(z>3)
# Out:
# (array([  22,   23,   24, ..., 9548, 9549, 9550], dtype=int64),
#  array([2, 2, 2, ..., 0, 0, 0], dtype=int64))

# %%
z.iloc[9550,0]
# Out:
# 3.341717864874006

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (8565, 21)

# %%
df.shape
# Out:
# (9551, 21)

# %%
print("old datashape:", df.shape[0])
print("New datashape:", df1.shape[0])
print("DataLoss Percentage is:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# old datashape: 9551
# New datashape: 8565
# DataLoss Percentage is: 10.323526332321222

# %%
There is 10% dataloss, so we will proceed with this dataloss.

# %%
df=df1 #Changing the new data df1 as df

# %%
df.shape
# Out:
# (8565, 21)

# %%
#Calculating Skewness

# %%
df['Country Code'].skew(),df['Longitude'].skew(),df['Latitude'].skew(),df['Cost'].skew(),df['Price range'].skew(),df['Aggregate_rating'].skew(),df['Votes'].skew()
# Out:
# (11.593933482324417,
#  -3.5299651212066814,
#  -3.1808729082735323,
#  3.718670768244618,
#  1.0292313484461288,
#  -0.8772623661930964,
#  3.6538427838503442)

# %%
skew=['Country Code', 'Longitude','Latitude','Cost','Price range','Aggregate_rating','Votes']

# %%
#Trying and reducing skewness using the PowerTransformer method

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
df[skew] = scaler.fit_transform(df[skew].values)
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\1853285395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[skew] = scaler.fit_transform(df[skew].values)

# %%
df['Country Code'].skew(),df['Longitude'].skew(),df['Latitude'].skew(),df['Cost'].skew(),df['Price range'].skew(),df['Aggregate_rating'].skew(),df['Votes'].skew()
# Out:
# (11.53283904042508,
#  -0.24936001415690334,
#  -2.5319370574876214,
#  0.044229175581303376,
#  0.24018477433826993,
#  -0.6310235971018237,
#  -0.008984340004196054)

# %%
Most of the skewness has been removed using the PowerTransformer method. I am going to remove the country code column, so does not matter if the 
skewness has not reduced in that column.

# %%
#Now lets remove some of the columns which are not contributing to the dataset in anyways.

# %%
df.drop(['Restaurant ID','Country Code', 'Address','Locality', 'Locality Verbose', 'Switch to order menu'], inplace=True, axis=1)
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\2491695741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Restaurant ID','Country Code', 'Address','Locality', 'Locality Verbose', 'Switch to order menu'], inplace=True, axis=1)

# %%
df.drop(['Restaurant Name', 'City'], inplace=True, axis=1)
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\762434957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Restaurant Name', 'City'], inplace=True, axis=1)

# %%
df.head(2)
# Out:
#    Longitude  Latitude                    Cuisines      Cost  \
# 0   7.096817 -2.870154  French, Japanese, Desserts  1.170136
# 1   7.094048 -2.870996                    Japanese  1.291498
#
#            Currency Table_booking Online_delivery Current_status  Price range  \
# 0  Botswana Pula(P)           Yes              No             No     1.385129
# 1  Botswana Pula(P)           Yes              No             No     1.385129
#
#    Aggregate_rating Rating color Rating text     Votes
# 0          1.972392   Dark Green   Excellent  1.410787
# 1          1.649065   Dark Green   Excellent  1.753948

# %%
#I have removed some of the columns but still we will check correlation of the variables

# %%
num_col=['Longitude', 'Latitude', 'Cost', 'Price range', 'Aggregate_rating', 'Votes']

# %%
#Checking for correlation coefficient values(numerical columns)

# %%
Corr=df[num_col].corr()
Corr
# Out:
#                   Longitude  Latitude      Cost  Price range  \
# Longitude          1.000000  0.579900  0.054889     0.075264
# Latitude           0.579900  1.000000 -0.028835    -0.112352
# Cost               0.054889 -0.028835  1.000000     0.817347
# Price range        0.075264 -0.112352  0.817347     1.000000
# Aggregate_rating   0.175121 -0.027884  0.409617     0.429224
# Votes              0.186750 -0.018102  0.505478     0.523711
#
#                   Aggregate_rating     Votes
# Longitude                 0.175121  0.186750
# Latitude                 -0.027884 -0.018102
# Cost                      0.409617  0.505478
# Price range               0.429224  0.523711
# Aggregate_rating          1.000000  0.857656
# Votes                     0.857656  1.000000

# %%
The correlation values interpratation:
Longitude and latitude are strongly positively related to each other. Longitude is weakly correlated to cost and price range. 
Latitude is negatively correlated to cost, price range, aggregate rating as well as votes. Cost is strongly positively correlated to price range,
votes, and Aggregate_rating whereas it is negatively and weakly correlated to latitude.  Price range is positively related to votes and a negatively
correlated value to latitude. 
Target variable(Aggregate_rating is strongly and positively correlated to Votes. It is not so strongly correlated but positively related to longitude
and cost but is weakly negatively related to latitude.  
Finally, Votes is stongly positively related to Aggregate_raing, cost and price range as well as weakly but positively related to longitude but is 
neatively  correlated to latitude.
From the graph, we note that: 1. months_as_customer and age are very strongly and positively correlated. 2. total_claim_amount, injury_claim, property_claim, vehicle_claim are positively and strongly correlated with each other. 3. month and date are negative correlated with each other. 4. We can check for multicollinearity issues with VIF as the corr() map shows many same values in each row. Since there are a lot of columns, it is cumbersome task. Hence will apply VIF.

# %%
plt.figure (figsize=(10, 8))
sns.heatmap(Corr, annot=True, fmt='.2f', cmap='viridis')
plt.xlabel("Figure", fontsize=15)
plt.ylabel("Feature Names", fontsize=15)
plt.title("Descriptive Graph", fontsize=20)
plt.show() #I am having some issue here with new version of the Anaconda and hence these graph value are not displayed properly

# %%
The graph and summary above also shows that Cost and Price range are positively and strongly related to each other.
Also Aggregate_rating and Votes are also strongly as well as positively correlated to each other. 
One can see that Aggregate_rating is negatively as well as weakly correlated to latitude indicated by dark color which is around 0.0. The longitude
and cost are not so strongly related to the target.

# %%
I am not going to delete the negatively correlated values as I have just a few columns. We will try to calculate 
the VIF factor 
and check for the colliniarity of the variables.

# %%
#Converting the categorical columns into numerical values using encoding techniques. Here am using LabelEncoder technique

# %%
encoder_col=['Cuisines', 'Currency','Table_booking', 'Online_delivery', 'Current_status','Rating color', 'Rating text', 'Votes']

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()
for i in encoder_col:
    df[i]=le.fit_transform(df[i])
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\2026206814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=le.fit_transform(df[i])
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\2026206814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=le.fit_transform(df[i])
# C:\Users\H P\AppData\Local\Temp\ipykernel_9800\2026206814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
We can see that all categorical values have been converted to numerical values successfully.

# %%
Build a regression model to predict the aggregate rating of a restaurant based on available features.
Split the dataset into training and testing sets and evaluate the model's performance using appropriate metrics.
Experiment with different algorithms (e.g.,linear regression, decision trees, random forest) and compare their performance.

# %%
Model Building

# %%
#Seperating x and y variables for training and testing and evaluating the model.

# %%
x=df.drop(['Aggregate_rating'], axis=1)
x
# Out:
#       Longitude  Latitude  Cuisines      Cost  Currency  Table_booking  \
# 0      7.096817 -2.870154       657  1.170136         0              1
# 1      7.094048 -2.870996       783  1.291498         0              1
# 2      7.102859 -2.869007      1271  3.044151         0              1
# 3      7.102785 -2.868725       794  1.605942         0              0
# 4      7.102998 -2.868788       793  1.605942         0              1
# ...         ...       ...       ...       ...       ...            ...
# 9432  -2.075973 -0.937919       552 -1.070567         4              0
# 9433  -2.075747 -0.929022       718  0.227962         4              0
# 9434  -2.076865 -0.953334      1364 -0.051401         4              0
# 9435  -2.074809 -0.954365       719 -0.190489         4              0
# 9436  -2.074670 -0.951102       715 -1.345007         4              0
#
#       Online_delivery  Current_status  Price range  Rating color  Rating text  \
# ...

# %%
y=df['Aggregate_rating']
y
# Out:
# 0       1.972392
# 1       1.649065
# 2       1.543945
# 3       2.082799
# 4       1.972392
#           ...
# 9432    1.038603
# 9433    1.543945
# 9434    1.440165
# 9435    1.649065
# 9436    1.038603
# Name: Aggregate_rating, Length: 8565, dtype: float64

# %%
#Variation Inflation Factor

# %%
#We will check crosscheck if there is multicolliniarity issue with the Variance Inflation Factor method

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF['VIF Values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
VIF['Features']=x.columns
VIF
# Out:
#     VIF Values         Features
# 0     1.656282        Longitude
# 1     1.769907         Latitude
# 2     4.286821         Cuisines
# 3     3.517246             Cost
# 4    10.321551         Currency
# 5     1.752226    Table_booking
# 6     1.578888  Online_delivery
# 7     1.017082   Current_status
# 8     3.270859      Price range
# 9     6.604367     Rating color
# 10    2.530846      Rating text
# 11    2.007870            Votes

# %%
All the VIF values are less than or equal to 10, and 10 being the threshold value. So there is no need to delete any column and 
there is no multicolliniarity issue.

# %%
#Scaling techniques to enable data to be uniform so as to get optimum results

# %%
from sklearn.preprocessing  import StandardScaler
st=StandardScaler()
x=pd.DataFrame(st.fit_transform(x))
x
# Out:
#             0         1         2         3          4         5         6   \
# 0     7.096817 -2.870154 -0.166259  1.170136 -13.447769  2.652303 -0.617978
# 1     7.094048 -2.870996  0.148814  1.291498 -13.447769  2.652303 -0.617978
# 2     7.102859 -2.869007  1.369094  3.044151 -13.447769  2.652303 -0.617978
# 3     7.102785 -2.868725  0.176320  1.605942 -13.447769 -0.377031 -0.617978
# 4     7.102998 -2.868788  0.173820  1.605942 -13.447769  2.652303 -0.617978
# ...        ...       ...       ...       ...        ...       ...       ...
# 8560 -2.075973 -0.937919 -0.428819 -1.070567  13.483930 -0.377031 -0.617978
# 8561 -2.075747 -0.929022 -0.013724  0.227962  13.483930 -0.377031 -0.617978
# 8562 -2.076865 -0.953334  1.601647 -0.051401  13.483930 -0.377031 -0.617978
# 8563 -2.074809 -0.954365 -0.011223 -0.190489  13.483930 -0.377031 -0.617978
# 8564 -2.074670 -0.951102 -0.021225 -1.345007  13.483930 -0.377031 -0.617978
#
#             7         8         9         10        11
# ...

# %%
#Designing a model to predict Aggregate_rating
#Training and testing the data

# %%
#Importing required metrics

# %%
#Finding the best model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.30, random_state=28)

# %%
from sklearn.linear_model import LinearRegression
maxAcc=0
maxRS=0
for i in range(1,100):
    x_train, x_test,y_train,y_test=train_test_split(x, y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print('max r2_score is', maxAcc, 'on ransdomstate' , maxRS)
# Out:
# max r2_score is 0.5250249828468283 on ransdomstate 28

# %%
The best r2_score is giving me 52% accuracy at a random_state of 28, which I will be deploying for various regression algorithms.

# %%
The data will be divided into training and testing as x and y on random_state of 28

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((5995, 12), (2570, 12), (5995,), (2570,))

# %%
#Deploying different algorithms to get best accuracy

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)
pred_lr=lr.predict(x_test)
print("R2_Score: ", r2_score(y_test, pred_lr)*100)
pred_train=lr.predict(x_train)
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print("Error:")
print("Mean squared error:", mean_squared_error(y_test, pred_lr))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_lr))
print("Root_mean_Squared_error:",  np.sqrt(mean_squared_error(y_test, pred_lr)))
# Out:
# R2_Score:  49.63931007278537
# R2_score on training data: 50.693766937934285
# Error:
# Mean squared error: 0.5124947347764188
# Mean_absolute_error 0.5845385385052622
# Root_mean_Squared_error: 0.7158873757627094

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train, y_train)
pred_rfr=rfr.predict(x_test) 
pred_train=rfr.predict(x_train)
print('R2_score', r2_score(y_test, pred_rfr)*100)
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_rfr))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_rfr))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_rfr)))
# Out:
# R2_score 97.78538552273727
# R2_score on training data: 99.6765293588502
# Mean squared error: 0.022536987892682683
# Mean_absolute_error 0.10204336598397304
# Root_mean_Squared_error: 0.1501232423466889

# %%
from sklearn.ensemble import ExtraTreesRegressor
etc=ExtraTreesRegressor()
etc.fit(x_train, y_train)
pred_etc=etc.predict(x_test)
pred_train=etc.predict(x_train)
print("R2_score",r2_score(y_test, pred_etc)*100)
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_etc))
print("Mean absolute error:", mean_absolute_error(y_test, pred_etc))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_etc)))
# Out:
# R2_score 97.66726479155199
# R2_score on training data: 99.99946501225683
# Mean squared error: 0.023739041575582702
# Mean absolute error: 0.10356835146675868
# Root_mean_Squared_error: 0.1540747921484326

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()
dtc.fit(x_train, y_train)
pred_dtc=dtc.predict(x_test) 
pred_train=dtc.predict(x_train)
print('R2_score', r2_score(y_test, pred_dtc)*100)
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_dtc))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_dtc))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_dtc)))
# Out:
# R2_score 95.81919313153473
# R2_score on training data 99.99946501225683
# Mean squared error: 0.042545912502435126
# Mean_absolute_error 0.13314929382466884
# Root_mean_Squared_error: 0.2062666053980506

# %%
from sklearn.linear_model import Lasso, Ridge
la=Lasso()
la.fit(x_train, y_train)
pred_la=la.predict(x_test) 
pred_train=la.predict(x_train)
print('R2_score', r2_score(y_test, pred_la)*100)
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_la))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_la))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_la)))
# Out:
# R2_score -0.0008372125874123171
# R2_score on training data 0.0
# Mean squared error: 1.0176568791800777
# Mean_absolute_error 0.8360606122773077
# Root_mean_Squared_error: 1.0087898092170031

# %%
from sklearn.linear_model import Ridge, Lasso
rd=Ridge()
rd.fit(x_train, y_train)
pred_rd=rd.predict(x_test) 
pred_train=rd.predict(x_train)
print('R2_score', r2_score(y_test, pred_rd)*100)
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_rd))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_rd))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score 49.63914765439035
# R2_score on training data 50.69376540313091
# Mean squared error: 0.5124963876245509
# Mean_absolute_error 0.5845518689522681
# Root_mean_Squared_error: 0.7158885301669184

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(x_train, y_train)
pred_knn=knn.predict(x_test) 
pred_train=knn.predict(x_train)
print('R2_score', r2_score(y_test, pred_knn))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_knn))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_knn))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score 0.9593776088387505
# R2_score on training data 97.26526098650595
# Mean squared error: 0.041339309716085154
# Mean_absolute_error 0.12071049462839803
# Root_mean_Squared_error: 0.2033207065600677

# %%
from sklearn.svm import SVR
svc=SVR()
svc.fit(x_train, y_train)
pred_svc=svc.predict(x_test) 
pred_train=svc.predict(x_train)
print('R2_score', r2_score(y_test, pred_svc)*100)
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_svc))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_svc))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_svc)))
# Out:
# R2_score 96.1690129424356
# R2_score on training data: 96.00792243373145
# Mean squared error: 0.03898597693629641
# Mean_absolute_error 0.14018499264564485
# Root_mean_Squared_error: 0.19744866911756181

# %%
From the above all regression algorithms, RandomForest and ExtraTrees are giving best accuracies at 97% on test datasets and on training datasets,
the accuracies are 99%. These values are almost near to each other, so there is no overfitting and underfitting either. 
Even the error values of mean_squared_error and mean absolute_error as well as root_mean_squared_error are also less than 1, which is a very good
indicator that the models are working excellent. We will check with cross validation method again below

# %%
#Cross Validiation Techniques

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_lr)-score.mean())
# Out:
# [0.41779776 0.36189987 0.52121056 0.49025547 0.52163162]
# 0.4625590543816719
# Difference between r2 score and validation score is: 0.03383404634618181

# %%
score=cross_val_score(dtc, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_dtc)-score.mean())
# Out:
# [0.95046222 0.95342121 0.9558752  0.95148241 0.95741834]
# 0.9537318759521215
# Difference between r2 score and validation score is: 0.004460055363225801

# %%
score=cross_val_score(etc, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_etc)-score.mean())
# Out:
# [0.97528825 0.97091127 0.97757596 0.97250887 0.97780241]
# 0.9748173508439439
# Difference between r2 score and validation score is: 0.0018552970715759454

# %%
score=cross_val_score(knn, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_knn)-score.mean())
# Out:
# [0.93790961 0.94600126 0.96126656 0.95913367 0.96461718]
# 0.9537856551626722
# Difference between r2 score and validation score is: 0.005591953676078232

# %%
score=cross_val_score(rfr, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_rfr)-score.mean())
# Out:
# [0.97617133 0.97287153 0.97838513 0.97390126 0.97754534]
# 0.9757749193320088
# Difference between r2 score and validation score is: 0.002078935895363898

# %%
score=cross_val_score(svc, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_svc)-score.mean())
# Out:
# [0.94481187 0.94822312 0.9584053  0.95973939 0.95385116]
# 0.9530061651592472
# Difference between r2 score and validation score is: 0.008683964265108757

# %%
score=cross_val_score(knn, x, y,cv=5, scoring='r2')
print (score)
print (score.mean())
print("Difference between r2 score and validation score is:", r2_score(y_test, pred_knn)-score.mean())
# Out:
# [0.93790961 0.94600126 0.96126656 0.95913367 0.96461718]
# 0.9537856551626722
# Difference between r2 score and validation score is: 0.005591953676078232

# %%
Cross validation technique is again showing etc and rfr accuracies as 97 with difference almost similar. I will go ahead with etc as it is 
showing the differene as 0.002 compared to rfr which is 0.003. We will go ahead wiht hyperparameter tuning for this model

# %%
Hyperparameter tuning for ExtraTreesRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[100], 'criterion':['squared_error'], 'max_depth':[None], 'min_samples_split':[2],
            'min_samples_leaf':[1], 'min_weight_fraction_leaf':[0.0], 'max_features':[1.0], 
            'max_leaf_nodes':[None], 'min_impurity_decrease':[0.0], 'bootstrap':[False], 
            'oob_score':[False], 'n_jobs':[None], 'random_state':[None], 'verbose':[0],
            'warm_start':[False], 'ccp_alpha':[0.0], 'max_samples':[None]}

# %%
parameters
# Out:
# {'n_estimators': [100],
#  'criterion': ['squared_error'],
#  'max_depth': [None],
#  'min_samples_split': [2],
#  'min_samples_leaf': [1],
#  'min_weight_fraction_leaf': [0.0],
#  'max_features': [1.0],
#  'max_leaf_nodes': [None],
#  'min_impurity_decrease': [0.0],
#  'bootstrap': [False],
#  'oob_score': [False],
#  'n_jobs': [None],
#  'random_state': [None],
#  'verbose': [0],
#  'warm_start': [False],
#  'ccp_alpha': [0.0],
#  'max_samples': [None]}

# %%
GCV=GridSearchCV(ExtraTreesRegressor(), parameters, cv=5)
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [False], 'ccp_alpha': [0.0],
#                          'criterion': ['squared_error'], 'max_depth': [None],
#                          'max_features': [1.0], 'max_leaf_nodes': [None],
#                          'max_samples': [None], 'min_impurity_decrease': [0.0],
#                          'min_samples_leaf': [1], 'min_samples_split': [2],
#                          'min_weight_fraction_leaf': [0.0],
#                          'n_estimators': [100], 'n_jobs': [None],
#                          'oob_score': [False], 'random_state': [None],
#                          'verbose': [0], 'warm_start': [False]})

# %%
Training the best model using parameters for ExtraTreesRegressor

# %%
Model=ExtraTreesRegressor(n_estimators=100,criterion='squared_error', max_depth=None,
      min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=1.0,
      max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=False,
      oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False,
      ccp_alpha=0.0, max_samples=None)
Model.fit(x_train, y_train)
pred=Model.predict(x_test)
print('R2_score', r2_score(y_test, pred))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred))
print("Mean_absolute_error", mean_absolute_error(y_test, pred))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score 0.9765499407025554
# R2_score on training data 96.00792243373145
# Mean squared error: 0.02386391436953029
# Mean_absolute_error 0.10381579272301004
# Root_mean_Squared_error: 0.15447949498082356

# %%
My new Model is giving 97% accuracy on training as well as testing data which is an excellent result.
Again the Mean_squared error is less than 1 showing at 0.023 points. 
          Mean_absolute_error is also less than 1 at 0.103 points.
          Root_mean_squared_error is 0.15.  All these are in acceptable range.
I can go ahead and save my Model as it is almost giving 100% results.

# %%
#saving the model for future endeavors

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)

# %%
import pickle
filename='Zomato.pkl'
pickle.dump(Model, open(filename, 'wb'))

# %%
#Re-loading the saved model

# %%
import pickle
loaded_Model=pickle.load(open('Zomato.pkl', 'rb'))
result=Model.score(x_test, y_test)
print(result*100)
# Out:
# 97.68359188845974

# %%
Model is giving me exactly same output of 97%. My Model is 100% accurate with good results.

# %%
Level: 3      Task 2:     Customer Preference Analysis

# %%
Analyze the relationship between the type of cuisine and the restaurant's rating

# %%
v = name_grp['Votes'].agg(np.sum).sort_values(ascending = False)[:10]  ## Here i selected 20 restaurant based on high votes
v
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_2208\2450627591.py:1: FutureWarning: The provided callable <function sum at 0x00000216013E0E00> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   v = name_grp['Votes'].agg(np.sum).sort_values(ascending = False)[:10]  ## Here i selected 20 restaurant based on high votes
# Cuisines
# North Indian, Mughlai             53747
# North Indian                      48967
# North Indian, Chinese             42012
# Cafe                              30657
# Chinese                           21925
# North Indian, Mughlai, Chinese    20115
# Fast Food                         17852
# South Indian                      16433
# Mughlai, North Indian             15275
# Italian                           14799
# Name: Votes, dtype: int64

# %%
We can see that North Indian, Mughal has 53747 votes. Others in list can be noted in the list. Lowest in 10 listings is Italian cuisine which has
14799 votes

# %%
name_grp = df.groupby('Cuisines')
v = name_grp['Votes'].agg(np.sum).sort_values(ascending = False)[:10]  ## Here i selected 20 restaurant based on high votes
plt.figure(figsize = (20,10))
ax = sns.barplot(y = v, x = v.index)
for i in ax.patches:
    ax.annotate(i.get_height().astype(int), (i.get_x()* 1.005, i.get_height()*1.005))

plt.title('Highest vote of restaurant', fontsize = 20)
plt.xlabel('Cuisine', fontsize = 15)
plt.ylabel('Frequecy', fontsize = 15)
plt.xticks(rotation =90)
plt.show()
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_2208\1023987682.py:2: FutureWarning: The provided callable <function sum at 0x00000216013E0E00> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   v = name_grp['Votes'].agg(np.sum).sort_values(ascending = False)[:10]  ## Here i selected 20 restaurant based on high votes

# %%
North Indian, Mughlai are the most popular uisines that have highest number of votes among the customers.

# %%
Determine if there are any specific cuisines that tend to receive higher ratings

# %%
LEVEL:3     TAST:3       Data Visualization

# %%
Create visualizations to represent the distribution of ratings using different charts (histogram, bar plot, etc.)

# %%
sns.histplot(df['Aggregate_rating'], bins=20)
plt.title('Distribution of Ratings')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
The distribution is a right skewed curve and is slightly normalized. There is a max at 0, which is 'no voting at all'. 
Again between 3 and 4, we have most ratings.

# %%
# Bar plot
ratings = df["Aggregate_rating"].head(10)
plt.figure(figsize=(8, 5))
ratings.value_counts().plot(kind='bar') 
plt.show()

# %%
Bar plot of 10 highest Aggregate_ratings are taken.

# %%
Compare the average ratings of different cuisines or cities using appropriate visualizations.

# %%
avg_cuisine = df.groupby('Cuisines')['Aggregate_rating'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
avg_cuisine.plot(kind='bar')
plt.xlabel('Cuisine')
plt.ylabel('Average Rating')
plt.title('Top 10 Cuisines by Average_Rating')
plt.show()

# %%
Avergage ratings according to cuisines are almost same for all Cuisines at 4.9. The Cuisines are shown in the figure.

# %%
avg_city = df.groupby('City')['Aggregate_rating'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
avg_cuisine.plot(kind='bar')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.title('Top 10 Cities by Average_Rating')
plt.show()

# %%
Avergage ratings according to Cities are almost same for all Cities also at 4.9. The 10 different Cities are shown in the plot.

# %%
Visualize the relationship between various features and the target variable to gain insights.

# %%
#Scatter plot for numerical columns

# %%
#Linear Model plots

# %%
numerical_columns = ["Price range", "Votes", "Country Code","Longitude","Latitude","Cost" ]

# %%
sns.lmplot(x='Country Code', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Country Code and target variable have a strong positive correlation between them.

# %%
sns.lmplot(x='Votes', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Votes and target variable are also moderately positivelycorrelated and as votes increase, Aggregate rating also increases

# %%
sns.lmplot(x='Price range', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Price range and target variable also are strongly positively correlated as shown in the plot

# %%
sns.lmplot(x='Cost', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Cost and target variable are also positively but weakly correlated.

# %%
sns.lmplot(x='Longitude', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Longitude has a negative relationship with target variable

# %%
sns.lmplot(x='Latitude', y='Aggregate_rating', data=df, palette='colorblind')

# %%
Latitude shows a neutral relationship with the target variable.  Not much difference with any change in latitude.

# %%
#######END OF THE PROJECT############

THANK YOU
